# %% [markdown]
# <font face="黑体" size=4 color=#8B0000> HP 滤波 </font>

# %%
import numpy as np
import time

# %%
def HP_Filter(Y,factor):
    #Y is the original array,factor is the penalty factor
    #Y is a column vector, type is list/array
    n=len(Y)
    if (n<4):
        print("The number of the sample must bigger than 4")
        exit()
    else:
        F=np.zeros([n,n])
        for i in range(0,n):
            if (i==0):
                F[i][0]=1
                F[i][1]=-2
                F[i][2]=1
            elif (i==1):
                F[i][0]=-2
                F[i][1]=5
                F[i][2]=-4
                F[i][3]=1
            elif(1<i<n-2):
                F[i][i-2]=1
                F[i][i-1]=-4
                F[i][i]=6
                F[i][i+1]=-4
                F[i][i+2]=1
            elif(i==n-2):
                F[i][-1]=-2
                F[i][-2]=5
                F[i][-3]=-4
                F[i][-4]=1
            else:
                F[i][-1]=1
                F[i][-2]=-2
                F[i][-3]=1
        F=np.matrix(F)#transfer into matrix
        I=np.matrix(np.identity(n))#generate identity matrix
        M=I+factor*F
        Y=np.matrix(Y)
        G=np.linalg.inv(M)*(Y.T)
        C=Y.T-G
        G=np.array(G)
        C=np.array(C)
    return G,C

# %% [markdown]
# <font face="黑体" size=4 color=#8B0000> This is the ituation of the USA </font>

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
from pylab import *
mpl.rcParams['font.sans-serif'] = ['SimHei'] # for the normal demonstration of chinese words
os.chdir('D:\各种材料\研究生\公众号\三、美林时钟模型')
data=pd.read_excel('美国CPI与生产指数同比较长时间.xlsx')
# to get CPI pic
CPI=data['CPI同比'].values.tolist()
[CPI_trend,CPI_circle]=HP_Filter(CPI,1600)
plt.plot(CPI,"b",label="同比序列")
plt.plot(CPI_trend,"r", label="趋势序列")
plt.plot(CPI_circle,"c",label="周期序列")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=0,ncol=3, mode="expand", borderaxespad=0.)
plt.plot()
# Out:
# []

# %%
#to get production indexing pic
production=data['生产指数同比'].values.tolist()
[production_trend,production_circle]=HP_Filter(production,1600)
plt.plot(production,"b",label="同比序列")
plt.plot(production_trend,"r",label="趋势序列")
plt.plot(production_circle,"c",label="周期序列")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=0,ncol=3, mode="expand", borderaxespad=0.)
plt.show()

# %% [markdown]
# <font size=4 color='08#0000' face='黑体'>用于判断周期的两个变量：产出缺口和CPI同比</font>

# %%
plt.plot(production_circle,"r",label="经济")
plt.plot(CPI,"c",label="通胀")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=0,ncol=3, mode="expand", borderaxespad=0.)
plt.show()

# %%
writer=pd.ExcelWriter("美国CPI与生产指数同比滤波较长时间.xlsx")
pro=pd.DataFrame(production,index=data['日期'])
pro_trend= pd.DataFrame(production_trend,index=data['日期'])
pro_circle=pd.DataFrame(production_circle,index=data['日期'])
cpi= pd.DataFrame(CPI,index=data['日期'])
cpi_trend= pd.DataFrame(CPI_trend,index=data['日期'])
cpi_circle= pd.DataFrame(CPI_circle,index=data['日期'])
frame=[pro,pro_trend,pro_circle,cpi,cpi_trend,cpi_circle]
result=pd.concat(frame,axis=1)
#result=pd.merge(pro,pro_trend,pro_circle,cpi,cpi_trend,cpi_circle,left_index=True)
result.columns=['pro index','pro_trend','产出缺口','CPI同比','cpi_trend','cpi_circle']
result.to_excel(writer,'page_1',float_format='%.5f')
writer.save()

# %% [markdown]
# <font face="黑体" size=4 color=#8B0000> The folowing is the situation of China </font>

# %% [markdown]
# <font size=4 color='08#0000' face='黑体'>经济发展用经济一致指数表示（月频），CPI也是月频</font>

# %%
data_china=pd.read_excel('中国经济一致指数通胀同比.xlsx')
# to get CPI pic
CPI_china=data_china['CPI同比'].values.tolist()
[CPI_trend_china,CPI_circle_china]=HP_Filter(CPI_china,1600)
plt.plot(CPI_china,"b",label="同比序列")
plt.plot(CPI_trend_china,"r", label="趋势序列")
plt.plot(CPI_circle_china,"c",label="周期序列")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=0,ncol=3, mode="expand", borderaxespad=0.)
plt.plot()
# Out:
# []

# %%
#to get production indexing pic
production_china=data_china['经济一致指数同比'].values.tolist()
[production_trend_china,production_circle_china]=HP_Filter(production_china,1600)
plt.plot(production_china,"b",label="同比序列")
plt.plot(production_trend_china,"r",label="趋势序列")
plt.plot(production_circle_china,"c",label="周期序列")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=0,ncol=3, mode="expand", borderaxespad=0.)
plt.show()

# %% [markdown]
# <font size=4 color='08#0000' face='黑体'>用于判断周期的的两个变量：产出缺口和CPI同比</font>

# %%
plt.plot(production_circle_china,"r",label="经济")
plt.plot(CPI_china,"c",label="通胀")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=0,ncol=3, mode="expand", borderaxespad=0.)
plt.show()

# %%
writer=pd.ExcelWriter("中国经济一致指数通胀滤波.xlsx")
pro_china= pd.DataFrame(production_china,index=data_china['日期'])
pro_trend_china= pd.DataFrame(production_trend_china,index=data_china['日期'])
pro_circle_china= pd.DataFrame(production_circle_china,index=data_china['日期'])
cpi_china= pd.DataFrame(CPI_china,index=data_china['日期'])
cpi_trend_china= pd.DataFrame(CPI_trend_china,index=data_china['日期'])
cpi_circle_china= pd.DataFrame(CPI_circle_china,index=data_china['日期'])
frame_china=[pro_china,pro_trend_china,pro_circle_china,cpi_china,cpi_trend_china,cpi_circle_china]
result_china=pd.concat(frame_china,axis=1)
#result=pd.merge(pro_china, cpi_china,left_index=True,right_index=True)
result_china.columns=['pro_china','pro_trend_china','产出缺口','CPI同比','cpi_trend_china','cpi_circle_china']
result_china.to_excel(writer,'page_1',float_format='%.5f')
writer.save()

# %% [markdown]
# <font face='黑体' size=4 color='08#0000' >经济发展用传统的GDP表示（季频）,CPI也为季频</font>

# %%
gdpcpi=pd.read_excel('中国GDPCPI同比.xlsx')
gdp_china=gdpcpi['GDP同比'].values.tolist()
[gdp_trend_china,gdp_circle_china]=HP_Filter(gdp_china,1600)
plt.plot(gdp_china,"b",label="同比序列")
plt.plot(gdp_trend_china,"r", label="趋势序列")
plt.plot(gdp_circle_china,"c",label="周期序列")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=0,ncol=3, mode="expand", borderaxespad=0.)
plt.plot()
# Out:
# []

# %%
gdpcpi=pd.read_excel('中国GDPCPI同比.xlsx')
cpi2_china=gdpcpi['CPI同比'].values.tolist()
[cpi2_trend_china,cpi2_circle_china]=HP_Filter(cpi2_china,1600)
plt.plot(cpi2_china,"b",label="同比序列")
plt.plot(cpi2_trend_china,"r", label="趋势序列")
plt.plot(cpi2_circle_china,"c",label="周期序列")
plt.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc=0,ncol=3, mode="expand", borderaxespad=0.)
plt.plot()
# Out:
# []

# %%
writer=pd.ExcelWriter("中国GDPCPI滤波.xlsx")
gdp_china=pd.DataFrame(gdp_china,index=gdpcpi['日期'])
gdp_trend_china=pd.DataFrame(gdp_trend_china,index=gdpcpi['日期'])
gdp_circle_china=pd.DataFrame(gdp_circle_china,index=gdpcpi['日期'])

cpi2_china= pd.DataFrame(cpi2_china,index=gdpcpi['日期'])
cpi2_trend_china= pd.DataFrame(cpi2_trend_china,index=gdpcpi['日期'])
cpi2_circle_china= pd.DataFrame(cpi2_circle_china,index=gdpcpi['日期'])

frame2_china=[gdp_china,gdp_trend_china,gdp_circle_china,cpi2_china,cpi2_trend_china,cpi2_circle_china]
result2_china=pd.concat(frame2_china,axis=1)
result2_china.columns=['gdp_china','gdp_trend_china','产出缺口','CPI同比','cpi_trend_china','cpi_circle_china']
result2_china.to_excel(writer,'page_1',float_format='%.5f')
writer.save()
