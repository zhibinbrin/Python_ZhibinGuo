# %%
import numpy as np 
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf

# %%
import os
os.chdir("D:\各种材料\研究生\公众号\三、美林时钟模型")
data=pd.read_excel(r"D:\各种材料\研究生\公众号\三、美林时钟模型\模型改进的探索.xlsx","M2一阶差分&CPI")
data=data.dropna(0)
data.index=data.日期
del data["日期"]
data.columns=["M2","M2变化量","CPI"]
#data.columns=["M2","CPI","PPI","Eco_Same","Eco_Ahead","Dollar_Index","Interest_rate","CPI_PPI"]
data.head()
# Out:
#                  M2   M2变化量  CPI
# 日期
# 1996-01-31  58401.0 -2349.5  9.0
# 1996-02-29  63778.0  5377.0  9.3
# 1996-03-31  64511.0   733.0  9.8
# 1996-04-30  65723.0  1212.0  9.7
# 1996-05-31  66880.0  1157.0  8.9

# %%
df=(data-data.mean())/data.std()#数据标准化
est = smf.ols(formula='CPI ~  M2变化量', data=df).fit() #前面的字符是显示了自变量与因变量
res=est.summary2()
res
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     -0.003
# Dependent Variable: CPI              AIC:                814.5366
# Date:               2020-02-08 21:38 BIC:                821.8485
# No. Observations:   286              Log-Likelihood:     -405.27
# Df Model:           1                F-statistic:        0.09388
# Df Residuals:       284              Prob (F-statistic): 0.760
# R-squared:          0.000            Scale:              1.0032
# -------------------------------------------------------------------
#              Coef.    Std.Err.     t      P>|t|     [0.025   0.975]
# -------------------------------------------------------------------
# Intercept    0.0000     0.0592   0.0000   1.0000   -0.1166   0.1166
# M2变化量        0.0182     0.0593   0.3064   0.7595   -0.0986   0.1350
# -----------------------------------------------------------------
# Omnibus:              32.793       Durbin-Watson:          0.058
# Prob(Omnibus):        0.000        Jarque-Bera (JB):       40.778
# Skew:                 0.850        Prob(JB):               0.000
# Kurtosis:             3.728        Condition No.:          1
# =================================================================
#
# """

# %% [markdown]
# <font color="08#0000" size=4 face="宋体">**滞后阶数检验**</font>

# %%
def Lag_Term(D,Vf,Vb,T):
    #D is the DataFrame, T is the lag term.
    #Vb(因变量),Vf(自变量)分别对应于滞后的，和提前的两隔经济变量的名字
    data_b=D[Vb]
    reg_b=data_b[T:].values
    data_f=D[Vf]
    if (T >0):
        reg_f=data_f[:-T].values
    else:
        reg_f=data_f[:].values 
    L=len(reg_b)
    reg_temp=np.array([reg_b,reg_f])
    reg_temp=reg_temp.T
    reg_final=pd.DataFrame(reg_temp,columns=[Vb,Vf])
    est = smf.ols(formula=Vb+"~"+Vf , data=reg_final).fit() #前面的字符是显示了自变量与因变量
    res=est.summary2()
    return res

# %%
Lag_Term(data,"M2变化量","CPI",15)
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                  Results: Ordinary least squares
# ==================================================================
# Model:              OLS              Adj. R-squared:     0.026
# Dependent Variable: CPI              AIC:                1166.1699
# Date:               2020-02-08 21:40 BIC:                1173.3742
# No. Observations:   271              Log-Likelihood:     -581.08
# Df Model:           1                F-statistic:        8.216
# Df Residuals:       269              Prob (F-statistic): 0.00448
# R-squared:          0.030            Scale:              4.2973
# --------------------------------------------------------------------
#               Coef.    Std.Err.      t      P>|t|    [0.025   0.975]
# --------------------------------------------------------------------
# Intercept     1.6357     0.1593   10.2677   0.0000   1.3221   1.9494
# M2变化量         0.0000     0.0000    2.8664   0.0045   0.0000   0.0001
# ------------------------------------------------------------------
# Omnibus:               26.252       Durbin-Watson:          0.139
# Prob(Omnibus):         0.000        Jarque-Bera (JB):       31.428
# Skew:                  0.747        Prob(JB):               0.000
# Kurtosis:              3.743        Condition No.:          13074
# ==================================================================
# * The condition number is large (1e+04). This might indicate
# strong multicollinearity or other numerical problems.
# """
